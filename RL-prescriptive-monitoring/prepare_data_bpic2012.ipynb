# %%
# A notbook to prepare the BPIC 2012 log

# %%
import pandas as pd
import numpy as np

# %%
case_id_col = "Case ID"
activity_col = "Activity"
resource_col = "Resource"
timestamp_col = "start_time"
label_col = "label"
pos_label = "deviant"  # positive outcome that will be predicted
neg_label = "regular"  # negative outcome 

dynamic_cat_cols = [
    "Activity",
    "Resource",
] 
static_cat_cols = []  
dynamic_num_cols = [
    "timesincelastevent",
    "timesincecasestart",
    "timesincemidnight",
    "event_nr",
    "month",
    "weekday",
    "hour",
    "open_cases",
]
static_num_cols = [
    "NumberOfOffers",
    "AMOUNT_REQ",
]

static_cols = static_cat_cols + static_num_cols + [case_id_col, label_col]
dynamic_cols = dynamic_cat_cols + dynamic_num_cols + [timestamp_col]
cat_cols = dynamic_cat_cols + static_cat_cols
freq_threshold = 10

# %%
datasets = ["bpic2012"]
for dataset_name in datasets:
    dataset_name = "%s"%dataset_name
    data = pd.read_csv("./data/%s/%s.csv"%(dataset_name, dataset_name), sep=",")

    # TO REMOVE WHITE SPACE FROM COLUMNS VALUES
    df_obj = data.select_dtypes(["object"])
    data[df_obj.columns] = df_obj.apply(lambda x: x.str.strip())

# %%
# Time Features

# %%
data[timestamp_col] = pd.to_datetime(data[timestamp_col])
data[resource_col] = (
    data.sort_values(timestamp_col, ascending=True)
    .groupby(case_id_col)[resource_col]
    .transform(lambda grp: grp.fillna(method="ffill"))
)
data.rename(columns=lambda x: x.replace("(case) ", ""), inplace=True)

# add event duration
data[timestamp_col] = pd.to_datetime(data[timestamp_col])
data["timesincemidnight"] = (
    data[timestamp_col].dt.hour * 60 + data[timestamp_col].dt.minute
)
data["month"] = data[timestamp_col].dt.month
data["weekday"] = data[timestamp_col].dt.weekday
data["hour"] = data[timestamp_col].dt.hour

# %%
data
# Out:
#         Case ID              start_time                 end_time  AMOUNT_REQ  \
# 0        173688 2011-09-30 22:38:44.546  2011-09-30T22:38:44.546       20000
# 1        173688 2011-09-30 22:38:44.880  2011-09-30T22:38:44.880       20000
# 2        173688 2011-09-30 22:39:37.906  2011-09-30T22:39:37.906       20000
# 3        173688 2011-10-01 09:36:46.437  2011-10-01T09:45:13.917       20000
# 4        173688 2011-10-01 09:42:43.308  2011-10-01T09:42:43.308       20000
# ...         ...                     ...                      ...         ...
# 164504   214373 2012-03-10 11:46:22.700  2012-03-10T11:50:54.881        8500
# 164505   214376 2012-02-29 22:51:16.799  2012-02-29T22:51:16.799       15000
# 164506   214376 2012-02-29 22:51:17.423  2012-02-29T22:51:17.423       15000
# 164507   214376 2012-03-01 08:26:46.736  2012-03-01T08:27:41.325       15000
# 164508   214376 2012-03-01 08:27:37.118  2012-03-01T08:27:37.118       15000
#
#                         REG_DATE                Activity  Resource  \
# 0       2011-09-30T22:38:44.546Z             A_SUBMITTED     112.0
# 1       2011-09-30T22:38:44.546Z       A_PARTLYSUBMITTED     112.0
# 2       2011-09-30T22:38:44.546Z           A_PREACCEPTED     112.0
# 3       2011-09-30T22:38:44.546Z  W_Completeren aanvraag     112.0
# 4       2011-09-30T22:38:44.546Z              A_ACCEPTED   10862.0
# ...                          ...                     ...       ...
# 164504  2012-02-29T22:43:09.766Z     W_Nabellen offertes   11119.0
# 164505  2012-02-29T22:51:16.799Z             A_SUBMITTED     112.0
# 164506  2012-02-29T22:51:16.799Z       A_PARTLYSUBMITTED     112.0
# 164507  2012-02-29T22:51:16.799Z      W_Afhandelen leads   11169.0
# 164508  2012-02-29T22:51:16.799Z              A_DECLINED   11169.0
#
#         timesincemidnight  month  weekday  hour
# 0                    1358      9        4    22
# 1                    1358      9        4    22
# 2                    1359      9        4    22
# 3                     576     10        5     9
# 4                     582     10        5     9
# ...                   ...    ...      ...   ...
# 164504                706      3        5    11
# 164505               1371      2        2    22
# 164506               1371      2        2    22
# 164507                506      3        3     8
# 164508                507      3        3     8
#
# [164509 rows x 11 columns]

# %%
# data[data["Case ID"] == 214310]

# %%
def extract_timestamp_features_2(group):
    group[timestamp_col] = pd.to_datetime(group[timestamp_col])

    group = group.sort_values(timestamp_col, ascending=False, kind="mergesort")

    tmp = group[timestamp_col] - group[timestamp_col].shift(-1)
    tmp = tmp.fillna(pd.Timedelta(seconds=0))
    group["timesincelastevent"] = tmp.apply(
        lambda x: float(x / np.timedelta64(1, "m"))
    )  # m is for minutes

    tmp = group[timestamp_col] - group[timestamp_col].iloc[-1]
    tmp = tmp.fillna(pd.Timedelta(seconds=0))
    group["timesincecasestart"] = tmp.apply(
        lambda x: float(x / np.timedelta64(1, "m"))
    )  # m is for minutes

    group = group.sort_values(timestamp_col, ascending=True, kind="mergesort")
    group["event_nr"] = range(1, len(group) + 1)

    group["timesincecasestart_days"] = group["timesincecasestart"] / 1440
    group["timesincecasestart_wks"] = group["timesincecasestart_days"] / 7

    group["timesincelastevent_days"] = group["timesincelastevent"] / 1440
    group["timesincelastevent_wks"] = group["timesincelastevent_days"] / 7

    try:
        #         pd.to_datetime(
        #             group[
        #                 group[activity_col].isin(
        #                     [
        #                         "A_APPROVED",
        #                         "A_REGISTERED",
        #                         "A_ACTIVATED",
        #                         "A_CANCELLED",
        #                         "A_DECLINED",
        #                     ]
        #                 )
        #             ][timestamp_col].values[0]
        #         )
        #         # print("True")

        last_e = pd.to_datetime(
            group[
                group[activity_col].isin(
                    [
                        "A_APPROVED",
                        "A_REGISTERED",
                        "A_ACTIVATED",
                        "A_CANCELLED",
                        "A_DECLINED",
                    ]
                )
            ][timestamp_col].values[0]
        )
        group["time_to_event_m"] = (
            last_e - pd.to_datetime(group[timestamp_col])
        ).dt.total_seconds() / 60.0
        group["time_to_event_m"] = group["time_to_event_m"].fillna(
            pd.Timedelta(seconds=0)
        )
        #     group["time_to_event_days"] = group["time_to_event_m"] / 1440
        #     group["time_to_event_wks"] = group["time_to_event_days"] / 7

        group["case_length"] = group["event_nr"].max()

        return group
    except:
        print(f"False, continue, {set(group['Case ID'])}")


def get_open_cases(date, dt_first_last_timestamps):
    return sum(
        (dt_first_last_timestamps["start_time"] <= date)
        & (dt_first_last_timestamps["end_time"] > date)
    )


# data = data.groupby(case_id_col).apply(extract_timestamp_features_2)
# data

# %%
# def extract_timestamp_features(group):
#     group[timestamp_col] = pd.to_datetime(group[timestamp_col])

#     group = group.sort_values(timestamp_col, ascending=False, kind='mergesort')

#     tmp = group[timestamp_col] - group[timestamp_col].shift(-1)
#     tmp = tmp.fillna(pd.Timedelta(seconds=0))
#     group["timesincelastevent"] = tmp.apply(lambda x: float(x / np.timedelta64(1, 'm')))  # m is for minutes

#     tmp = group[timestamp_col] - group[timestamp_col].iloc[-1]
#     tmp = tmp.fillna(pd.Timedelta(seconds=0))
#     group["timesincecasestart"] = tmp.apply(lambda x: float(x / np.timedelta64(1, 'm')))  # m is for minutes

#     group = group.sort_values(timestamp_col, ascending=True, kind='mergesort')
#     group["event_nr"] = range(1, len(group) + 1)
    
#     group["timesincecasestart_days"] = group["timesincecasestart"] / 1440
#     group["timesincecasestart_wks"] = group["timesincecasestart_days"] / 7

#     group["timesincelastevent_days"] = group["timesincelastevent"] / 1440
#     group["timesincelastevent_wks"] = group["timesincelastevent_days"] / 7

#     last_e = pd.to_datetime(
#     group[
#         group[activity_col].isin(
#             ["A_APPROVED", "A_REGISTERED", "A_ACTIVATED", "A_CANCELLED", "A_DECLINED",]
#         )
#     ][timestamp_col].values[0]
#     )
#     group["time_to_event_m"] = (
#         last_e - pd.to_datetime(group[timestamp_col])
#     ).dt.total_seconds() / 60.0
#     group["time_to_event_m"] = group["time_to_event_m"].fillna(pd.Timedelta(seconds=0))
# #     group["time_to_event_days"] = group["time_to_event_m"] / 1440
# #     group["time_to_event_wks"] = group["time_to_event_days"] / 7
    
#     group['case_length'] = group["event_nr"].max()

#     return group

# def get_open_cases(date, dt_first_last_timestamps):
#     return sum((dt_first_last_timestamps["start_time"] <= date) & (dt_first_last_timestamps["end_time"] > date))

# %%
print("Extracting timestamp features...")
data = data.groupby(case_id_col).apply(extract_timestamp_features_2)

print("Extracting open cases...")
data = data.sort_values([timestamp_col], ascending=True, kind="mergesort").reset_index(
    drop=True
)
dt_first_last_timestamps = data.groupby(case_id_col)[timestamp_col].agg([min, max])
dt_first_last_timestamps.columns = ["start_time", "end_time"]
data["open_cases"] = data[timestamp_col].apply(
    lambda x: get_open_cases(x, dt_first_last_timestamps)
)
# Out:
# Extracting timestamp features...
# False, continue, {197219}
# False, continue, {197437}
# False, continue, {198017}
# False, continue, {198996}
# False, continue, {199678}
# False, continue, {200389}
# False, continue, {200725}
# False, continue, {201042}
# False, continue, {202038}
# False, continue, {202307}
# False, continue, {202358}
# False, continue, {202521}
# False, continue, {203362}
# False, continue, {203428}
# False, continue, {203504}
# False, continue, {203630}
# False, continue, {204131}
# False, continue, {204496}
# False, continue, {205199}
# False, continue, {205334}
# False, continue, {205604}
# False, continue, {205694}
# False, continue, {205990}
# False, continue, {206002}
# False, continue, {206177}
# False, continue, {206192}
# False, continue, {206264}
# False, continue, {206558}
# False, continue, {206600}
# False, continue, {206636}
# False, continue, {206721}
# False, continue, {206886}
# False, continue, {207011}
# False, continue, {207032}
# False, continue, {207389}
# False, continue, {207434}
# False, continue, {207777}
# False, continue, {207939}
# False, continue, {208097}
# False, continue, {208100}
# False, continue, {208259}
# False, continue, {208433}
# False, continue, {208481}
# False, continue, {208490}
# False, continue, {208535}
# False, continue, {208553}
# False, continue, {208589}
# False, continue, {208610}
# False, continue, {208628}
# False, continue, {208652}
# False, continue, {208658}
# False, continue, {208661}
# False, continue, {208748}
# False, continue, {208760}
# False, continue, {208769}
# False, continue, {208796}
# False, continue, {208835}
# False, continue, {208856}
# False, continue, {208859}
# False, continue, {208862}
# False, continue, {208868}
# False, continue, {209051}
# False, continue, {209060}
# False, continue, {209066}
# False, continue, {209111}
# False, continue, {209147}
# False, continue, {209227}
# False, continue, {209248}
# False, continue, {209251}
# False, continue, {209308}
# False, continue, {209311}
# False, continue, {209377}
# False, continue, {209455}
# False, continue, {209467}
# False, continue, {209470}
# False, continue, {209499}
# False, continue, {209508}
# False, continue, {209529}
# False, continue, {209586}
# False, continue, {209595}
# False, continue, {209601}
# False, continue, {209625}
# False, continue, {209628}
# False, continue, {209634}
# False, continue, {209640}
# False, continue, {209655}
# False, continue, {209670}
# False, continue, {209679}
# False, continue, {209682}
# False, continue, {209775}
# False, continue, {209832}
# False, continue, {209844}
# False, continue, {209895}
# False, continue, {209904}
# False, continue, {209916}
# False, continue, {209945}
# False, continue, {210026}
# False, continue, {210047}
# False, continue, {210050}
# False, continue, {210074}
# False, continue, {210095}
# False, continue, {210104}
# False, continue, {210128}
# False, continue, {210137}
# False, continue, {210152}
# False, continue, {210161}
# False, continue, {210191}
# False, continue, {210203}
# False, continue, {210209}
# False, continue, {210218}
# False, continue, {210254}
# False, continue, {210257}
# False, continue, {210293}
# False, continue, {210305}
# False, continue, {210308}
# False, continue, {210332}
# False, continue, {210341}
# False, continue, {210425}
# False, continue, {210452}
# False, continue, {210473}
# False, continue, {210539}
# False, continue, {210554}
# False, continue, {210557}
# False, continue, {210575}
# False, continue, {210584}
# False, continue, {210590}
# False, continue, {210602}
# False, continue, {210611}
# False, continue, {210626}
# False, continue, {210650}
# False, continue, {210653}
# False, continue, {210662}
# False, continue, {210701}
# False, continue, {210710}
# False, continue, {210734}
# False, continue, {210737}
# False, continue, {210761}
# False, continue, {210770}
# False, continue, {210812}
# False, continue, {210836}
# False, continue, {210848}
# False, continue, {210860}
# False, continue, {210878}
# False, continue, {210911}
# False, continue, {210957}
# False, continue, {210972}
# False, continue, {210984}
# False, continue, {211032}
# False, continue, {211050}
# False, continue, {211053}
# False, continue, {211071}
# False, continue, {211101}
# False, continue, {211104}
# False, continue, {211140}
# False, continue, {211182}
# False, continue, {211197}
# False, continue, {211233}
# False, continue, {211242}
# False, continue, {211260}
# False, continue, {211278}
# False, continue, {211299}
# False, continue, {211314}
# False, continue, {211329}
# False, continue, {211332}
# False, continue, {211384}
# False, continue, {211390}
# False, continue, {211432}
# False, continue, {211456}
# False, continue, {211459}
# False, continue, {211489}
# False, continue, {211525}
# False, continue, {211552}
# False, continue, {211567}
# False, continue, {211570}
# False, continue, {211594}
# False, continue, {211603}
# False, continue, {211624}
# False, continue, {211633}
# False, continue, {211649}
# False, continue, {211691}
# False, continue, {211709}
# False, continue, {211712}
# False, continue, {211715}
# False, continue, {211742}
# False, continue, {211748}
# False, continue, {211751}
# False, continue, {211778}
# False, continue, {211790}
# False, continue, {211811}
# False, continue, {211829}
# False, continue, {211841}
# False, continue, {211874}
# False, continue, {211904}
# False, continue, {211913}
# False, continue, {211925}
# False, continue, {211940}
# False, continue, {211949}
# False, continue, {211964}
# False, continue, {211967}
# False, continue, {211970}
# False, continue, {211988}
# False, continue, {212040}
# False, continue, {212055}
# False, continue, {212082}
# False, continue, {212115}
# False, continue, {212121}
# False, continue, {212139}
# False, continue, {212154}
# False, continue, {212157}
# False, continue, {212163}
# False, continue, {212166}
# False, continue, {212172}
# False, continue, {212223}
# False, continue, {212232}
# False, continue, {212238}
# False, continue, {212268}
# False, continue, {212271}
# False, continue, {212280}
# False, continue, {212283}
# False, continue, {212286}
# False, continue, {212301}
# False, continue, {212313}
# False, continue, {212331}
# False, continue, {212340}
# False, continue, {212349}
# False, continue, {212361}
# False, continue, {212370}
# False, continue, {212419}
# False, continue, {212440}
# False, continue, {212449}
# False, continue, {212458}
# False, continue, {212464}
# False, continue, {212467}
# False, continue, {212491}
# False, continue, {212497}
# False, continue, {212521}
# False, continue, {212530}
# False, continue, {212548}
# False, continue, {212566}
# False, continue, {212569}
# False, continue, {212605}
# False, continue, {212611}
# False, continue, {212614}
# False, continue, {212617}
# False, continue, {212623}
# False, continue, {212635}
# False, continue, {212647}
# False, continue, {212665}
# False, continue, {212689}
# False, continue, {212701}
# False, continue, {212710}
# False, continue, {212755}
# False, continue, {212779}
# False, continue, {212806}
# False, continue, {212812}
# False, continue, {212824}
# False, continue, {212833}
# False, continue, {212836}
# False, continue, {212842}
# False, continue, {212848}
# False, continue, {212878}
# False, continue, {212887}
# False, continue, {212908}
# False, continue, {212911}
# False, continue, {212914}
# False, continue, {212923}
# False, continue, {212932}
# False, continue, {212953}
# False, continue, {212965}
# False, continue, {212974}
# False, continue, {212977}
# False, continue, {212989}
# False, continue, {212995}
# False, continue, {213004}
# False, continue, {213007}
# False, continue, {213013}
# False, continue, {213031}
# False, continue, {213046}
# False, continue, {213064}
# False, continue, {213070}
# False, continue, {213082}
# False, continue, {213123}
# False, continue, {213135}
# False, continue, {213141}
# False, continue, {213150}
# False, continue, {213189}
# False, continue, {213198}
# False, continue, {213210}
# False, continue, {213228}
# False, continue, {213231}
# False, continue, {213249}
# False, continue, {213264}
# False, continue, {213267}
# False, continue, {213276}
# False, continue, {213279}
# False, continue, {213282}
# False, continue, {213288}
# False, continue, {213291}
# False, continue, {213294}
# False, continue, {213303}
# False, continue, {213330}
# False, continue, {213339}
# False, continue, {213366}
# False, continue, {213375}
# False, continue, {213381}
# False, continue, {213390}
# False, continue, {213393}
# False, continue, {213402}
# False, continue, {213405}
# False, continue, {213414}
# False, continue, {213420}
# False, continue, {213426}
# False, continue, {213438}
# False, continue, {213456}
# False, continue, {213474}
# False, continue, {213477}
# False, continue, {213492}
# False, continue, {213507}
# False, continue, {213534}
# False, continue, {213543}
# False, continue, {213572}
# False, continue, {213575}
# False, continue, {213615}
# False, continue, {213621}
# False, continue, {213630}
# False, continue, {213639}
# False, continue, {213651}
# False, continue, {213660}
# False, continue, {213669}
# False, continue, {213690}
# False, continue, {213696}
# False, continue, {213699}
# False, continue, {213714}
# False, continue, {213729}
# False, continue, {213738}
# False, continue, {213750}
# False, continue, {213768}
# False, continue, {213771}
# False, continue, {213783}
# False, continue, {213795}
# False, continue, {213807}
# False, continue, {213813}
# False, continue, {213837}
# False, continue, {213849}
# False, continue, {213855}
# False, continue, {213858}
# False, continue, {213870}
# False, continue, {213879}
# False, continue, {213888}
# False, continue, {213891}
# False, continue, {213894}
# False, continue, {213918}
# False, continue, {213921}
# False, continue, {213927}
# False, continue, {213939}
# False, continue, {213942}
# False, continue, {213948}
# False, continue, {213957}
# False, continue, {213960}
# False, continue, {213963}
# False, continue, {213966}
# False, continue, {213969}
# False, continue, {213980}
# False, continue, {213998}
# False, continue, {214001}
# False, continue, {214022}
# False, continue, {214028}
# False, continue, {214031}
# False, continue, {214046}
# False, continue, {214055}
# False, continue, {214064}
# False, continue, {214070}
# False, continue, {214088}
# False, continue, {214091}
# False, continue, {214106}
# False, continue, {214121}
# False, continue, {214172}
# False, continue, {214175}
# False, continue, {214181}
# False, continue, {214184}
# False, continue, {214205}
# False, continue, {214208}
# False, continue, {214211}
# False, continue, {214223}
# False, continue, {214241}
# False, continue, {214247}
# False, continue, {214262}
# False, continue, {214283}
# False, continue, {214286}
# False, continue, {214289}
# False, continue, {214304}
# False, continue, {214310}
# False, continue, {214313}
# False, continue, {214346}
# False, continue, {214352}
# False, continue, {214355}
# False, continue, {214358}
# False, continue, {214364}
# False, continue, {214373}
# Extracting open cases...

# %%
data = data.sort_values(timestamp_col, ascending=True, kind="mergesort")
data
# Out:
#         Case ID              start_time                 end_time  AMOUNT_REQ  \
# 0        173688 2011-09-30 22:38:44.546  2011-09-30T22:38:44.546       20000
# 1        173688 2011-09-30 22:38:44.880  2011-09-30T22:38:44.880       20000
# 2        173688 2011-09-30 22:39:37.906  2011-09-30T22:39:37.906       20000
# 3        173691 2011-10-01 06:08:58.256  2011-10-01T06:08:58.256        5000
# 4        173691 2011-10-01 06:09:02.195  2011-10-01T06:09:02.195        5000
# ...         ...                     ...                      ...         ...
# 156957   208901 2012-03-14 14:31:28.859  2012-03-14T14:31:28.859       11000
# 156958   206615 2012-03-14 14:33:57.651  2012-03-14T14:33:57.651       22000
# 156959   206615 2012-03-14 14:33:57.651  2012-03-14T14:33:57.651       22000
# 156960   206615 2012-03-14 14:33:57.651  2012-03-14T14:33:57.651       22000
# 156961   206615 2012-03-14 14:33:57.651  2012-03-14T14:33:57.651       22000
#
#                         REG_DATE           Activity  Resource  \
# 0       2011-09-30T22:38:44.546Z        A_SUBMITTED     112.0
# 1       2011-09-30T22:38:44.546Z  A_PARTLYSUBMITTED     112.0
# 2       2011-09-30T22:38:44.546Z      A_PREACCEPTED     112.0
# 3       2011-10-01T06:08:58.256Z        A_SUBMITTED     112.0
# 4       2011-10-01T06:08:58.256Z  A_PARTLYSUBMITTED     112.0
# ...                          ...                ...       ...
# 156957  2012-02-13T14:50:41.425Z       A_REGISTERED   11339.0
# 156958  2012-02-05T15:42:18.178Z         A_APPROVED   10809.0
# 156959  2012-02-05T15:42:18.178Z       A_REGISTERED   10809.0
# 156960  2012-02-05T15:42:18.178Z         O_ACCEPTED   10809.0
# 156961  2012-02-05T15:42:18.178Z        A_ACTIVATED   10809.0
#
#         timesincemidnight  month  weekday  ...  timesincelastevent  \
# 0                    1358      9        4  ...            0.000000
# 1                    1358      9        4  ...            0.005567
# 2                    1359      9        4  ...            0.883767
# 3                     368     10        5  ...            0.000000
# 4                     369     10        5  ...            0.065650
# ...                   ...    ...      ...  ...                 ...
# 156957                871      3        2  ...           19.133400
# 156958                873      3        2  ...            0.000000
# 156959                873      3        2  ...            0.000000
# 156960                873      3        2  ...            0.000000
# 156961                873      3        2  ...           33.689733
#
#         timesincecasestart  event_nr  timesincecasestart_days  \
# 0                 0.000000         1                 0.000000
# 1                 0.005567         2                 0.000004
# 2                 0.889333         3                 0.000618
# 3                 0.000000         1                 0.000000
# 4                 0.065650         2                 0.000046
# ...                    ...       ...                      ...
# 156957        43180.790567        20                29.986660
# 156958        54651.657883        45                37.952540
# 156959        54651.657883        46                37.952540
# 156960        54651.657883        47                37.952540
# 156961        54651.657883        48                37.952540
#
#         timesincecasestart_wks  timesincelastevent_days  \
# 0                 0.000000e+00                 0.000000
# 1                 5.522487e-07                 0.000004
# 2                 8.822751e-05                 0.000614
# 3                 0.000000e+00                 0.000000
# 4                 6.512897e-06                 0.000046
# ...                        ...                      ...
# 156957            4.283809e+00                 0.013287
# 156958            5.421791e+00                 0.000000
# 156959            5.421791e+00                 0.000000
# 156960            5.421791e+00                 0.000000
# 156961            5.421791e+00                 0.023396
#
#         timesincelastevent_wks  time_to_event_m  case_length  open_cases
# 0                 0.000000e+00     17878.744667           18           1
# 1                 5.522487e-07     17878.739100           18           1
# 2                 8.767526e-05     17877.855333           18           1
# 3                 0.000000e+00     13328.467517           26           2
# 4                 6.512897e-06     13328.401867           26           2
# ...                        ...              ...          ...         ...
# 156957            1.898155e-03         0.000000           20           1
# 156958            0.000000e+00         0.000000           48           0
# 156959            0.000000e+00         0.000000           48           0
# 156960            0.000000e+00         0.000000           48           0
# 156961            3.342235e-03         0.000000           48           0
#
# [156962 rows x 21 columns]

# %%
# Add label
# Positive, i.e., we need to predict : "A_CANCELLED", "A_DECLINED": pos_label
# negative : "A_APPROVED", "A_REGISTERED", "A_ACTIVATED": neg_label

# %%
def add_lable(group):
    activities1 = ["A_APPROVED", "A_REGISTERED", "A_ACTIVATED"]
    activities2 = ["A_CANCELLED", "A_DECLINED"]

    if not group[group["Activity"].isin(activities1)].empty:
        group["label"] = neg_label
        return group
    elif not group[group["Activity"].isin(activities2)].empty:
        group["label"] = pos_label
        return group
    else:
        print("\nNot Complete\n")
        return None


print("Add Label ...")
data = data.groupby(case_id_col, as_index=False).apply(add_lable).reset_index(drop=True)
data
# Out:
# Add Label ...
#         Case ID              start_time                 end_time  AMOUNT_REQ  \
# 0        173688 2011-09-30 22:38:44.546  2011-09-30T22:38:44.546       20000
# 1        173688 2011-09-30 22:38:44.880  2011-09-30T22:38:44.880       20000
# 2        173688 2011-09-30 22:39:37.906  2011-09-30T22:39:37.906       20000
# 3        173691 2011-10-01 06:08:58.256  2011-10-01T06:08:58.256        5000
# 4        173691 2011-10-01 06:09:02.195  2011-10-01T06:09:02.195        5000
# ...         ...                     ...                      ...         ...
# 156957   208901 2012-03-14 14:31:28.859  2012-03-14T14:31:28.859       11000
# 156958   206615 2012-03-14 14:33:57.651  2012-03-14T14:33:57.651       22000
# 156959   206615 2012-03-14 14:33:57.651  2012-03-14T14:33:57.651       22000
# 156960   206615 2012-03-14 14:33:57.651  2012-03-14T14:33:57.651       22000
# 156961   206615 2012-03-14 14:33:57.651  2012-03-14T14:33:57.651       22000
#
#                         REG_DATE           Activity  Resource  \
# 0       2011-09-30T22:38:44.546Z        A_SUBMITTED     112.0
# 1       2011-09-30T22:38:44.546Z  A_PARTLYSUBMITTED     112.0
# 2       2011-09-30T22:38:44.546Z      A_PREACCEPTED     112.0
# 3       2011-10-01T06:08:58.256Z        A_SUBMITTED     112.0
# 4       2011-10-01T06:08:58.256Z  A_PARTLYSUBMITTED     112.0
# ...                          ...                ...       ...
# 156957  2012-02-13T14:50:41.425Z       A_REGISTERED   11339.0
# 156958  2012-02-05T15:42:18.178Z         A_APPROVED   10809.0
# 156959  2012-02-05T15:42:18.178Z       A_REGISTERED   10809.0
# 156960  2012-02-05T15:42:18.178Z         O_ACCEPTED   10809.0
# 156961  2012-02-05T15:42:18.178Z        A_ACTIVATED   10809.0
#
#         timesincemidnight  month  weekday  ...  timesincecasestart  event_nr  \
# 0                    1358      9        4  ...            0.000000         1
# 1                    1358      9        4  ...            0.005567         2
# 2                    1359      9        4  ...            0.889333         3
# 3                     368     10        5  ...            0.000000         1
# 4                     369     10        5  ...            0.065650         2
# ...                   ...    ...      ...  ...                 ...       ...
# 156957                871      3        2  ...        43180.790567        20
# 156958                873      3        2  ...        54651.657883        45
# 156959                873      3        2  ...        54651.657883        46
# 156960                873      3        2  ...        54651.657883        47
# 156961                873      3        2  ...        54651.657883        48
#
#         timesincecasestart_days  timesincecasestart_wks  \
# 0                      0.000000            0.000000e+00
# 1                      0.000004            5.522487e-07
# 2                      0.000618            8.822751e-05
# 3                      0.000000            0.000000e+00
# 4                      0.000046            6.512897e-06
# ...                         ...                     ...
# 156957                29.986660            4.283809e+00
# 156958                37.952540            5.421791e+00
# 156959                37.952540            5.421791e+00
# 156960                37.952540            5.421791e+00
# 156961                37.952540            5.421791e+00
#
#         timesincelastevent_days  timesincelastevent_wks  time_to_event_m  \
# 0                      0.000000            0.000000e+00     17878.744667
# 1                      0.000004            5.522487e-07     17878.739100
# 2                      0.000614            8.767526e-05     17877.855333
# 3                      0.000000            0.000000e+00     13328.467517
# 4                      0.000046            6.512897e-06     13328.401867
# ...                         ...                     ...              ...
# 156957                 0.013287            1.898155e-03         0.000000
# 156958                 0.000000            0.000000e+00         0.000000
# 156959                 0.000000            0.000000e+00         0.000000
# 156960                 0.000000            0.000000e+00         0.000000
# 156961                 0.023396            3.342235e-03         0.000000
#
#         case_length  open_cases    label
# 0                18           1  regular
# 1                18           1  regular
# 2                18           1  regular
# 3                26           2  regular
# 4                26           2  regular
# ...             ...         ...      ...
# 156957           20           1  regular
# 156958           48           0  regular
# 156959           48           0  regular
# 156960           48           0  regular
# 156961           48           0  regular
#
# [156962 rows x 22 columns]

# %%
# Add treatment:
# Offer prepared and transmitted to applicant:
# O_SENT

# %%
set(data.Activity)
# Out:
# {'A_ACCEPTED',
#  'A_ACTIVATED',
#  'A_APPROVED',
#  'A_CANCELLED',
#  'A_DECLINED',
#  'A_FINALIZED',
#  'A_PARTLYSUBMITTED',
#  'A_PREACCEPTED',
#  'A_REGISTERED',
#  'A_SUBMITTED',
#  'O_ACCEPTED',
#  'O_CANCELLED',
#  'O_CREATED',
#  'O_DECLINED',
#  'O_SELECTED',
#  'O_SENT',
#  'O_SENT_BACK',
#  'W_Afhandelen leads',
#  'W_Beoordelen fraude',
#  'W_Completeren aanvraag',
#  'W_Nabellen incomplete dossiers',
#  'W_Nabellen offertes',
#  'W_Valideren aanvraag'}

# %%
def add_Offere(group):
    # get all observations with O_Created activity
    tmp_df = group[group[activity_col] == "O_SENT"]  # to count offers
    # count numbe rof offers for each case
    tmp_df2 = pd.DataFrame(
        tmp_df.groupby([case_id_col])[activity_col].count()
    ).reset_index()
    tmp_df2.columns = [case_id_col, "NumberOfOffers"]
    group = pd.merge(tmp_df2, group, on=case_id_col)
    return group


print("Add no of offeres ...")
data_offeres = add_Offere(data)
data_offeres
# Out:
# Add no of offeres ...
#         Case ID  NumberOfOffers              start_time  \
# 0        173688               1 2011-09-30 22:38:44.546
# 1        173688               1 2011-09-30 22:38:44.880
# 2        173688               1 2011-09-30 22:39:37.906
# 3        173688               1 2011-10-01 09:36:46.437
# 4        173688               1 2011-10-01 09:42:43.308
# ...         ...             ...                     ...
# 115120   214361               1 2012-03-07 08:01:59.877
# 115121   214361               1 2012-03-12 15:12:08.468
# 115122   214361               1 2012-03-13 10:03:00.346
# 115123   214361               1 2012-03-13 10:21:42.128
# 115124   214361               1 2012-03-13 10:21:42.128
#
#                        end_time  AMOUNT_REQ                  REG_DATE  \
# 0       2011-09-30T22:38:44.546       20000  2011-09-30T22:38:44.546Z
# 1       2011-09-30T22:38:44.880       20000  2011-09-30T22:38:44.546Z
# 2       2011-09-30T22:39:37.906       20000  2011-09-30T22:38:44.546Z
# 3       2011-10-01T09:45:13.917       20000  2011-09-30T22:38:44.546Z
# 4       2011-10-01T09:42:43.308       20000  2011-09-30T22:38:44.546Z
# ...                         ...         ...                       ...
# 115120  2012-03-07T08:01:59.877        5000  2012-02-29T22:11:37.974Z
# 115121  2012-03-12T15:12:34.634        5000  2012-02-29T22:11:37.974Z
# 115122  2012-03-13T10:21:45.661        5000  2012-02-29T22:11:37.974Z
# 115123  2012-03-13T10:21:42.128        5000  2012-02-29T22:11:37.974Z
# 115124  2012-03-13T10:21:42.128        5000  2012-02-29T22:11:37.974Z
#
#                       Activity  Resource  timesincemidnight  month  ...  \
# 0                  A_SUBMITTED     112.0               1358      9  ...
# 1            A_PARTLYSUBMITTED     112.0               1358      9  ...
# 2                A_PREACCEPTED     112.0               1359      9  ...
# 3       W_Completeren aanvraag     112.0                576     10  ...
# 4                   A_ACCEPTED   10862.0                582     10  ...
# ...                        ...       ...                ...    ...  ...
# 115120             O_SENT_BACK   10899.0                481      3  ...
# 115121    W_Valideren aanvraag   10809.0                912      3  ...
# 115122    W_Valideren aanvraag   10138.0                603      3  ...
# 115123              A_DECLINED   10138.0                621      3  ...
# 115124              O_DECLINED   10138.0                621      3  ...
#
#         timesincecasestart  event_nr  timesincecasestart_days  \
# 0                 0.000000         1                 0.000000
# 1                 0.005567         2                 0.000004
# 2                 0.889333         3                 0.000618
# 3               658.031517         4                 0.456966
# 4               663.979367         5                 0.461097
# ...                    ...       ...                      ...
# 115120         9230.365033        14                 6.409976
# 115121        16860.508217        15                11.708686
# 115122        17991.372850        16                12.494009
# 115123        18010.069217        17                12.506993
# 115124        18010.069217        18                12.506993
#
#         timesincecasestart_wks  timesincelastevent_days  \
# 0                 0.000000e+00                 0.000000
# 1                 5.522487e-07                 0.000004
# 2                 8.822751e-05                 0.000614
# 3                 6.528090e-02                 0.456349
# 4                 6.587097e-02                 0.004130
# ...                        ...                      ...
# 115120            9.157108e-01                 0.000773
# 115121            1.672669e+00                 5.298711
# 115122            1.784858e+00                 0.785323
# 115123            1.786713e+00                 0.000000
# 115124            1.786713e+00                 0.012984
#
#         timesincelastevent_wks  time_to_event_m  case_length  open_cases  \
# 0                 0.000000e+00     17878.744667           18           1
# 1                 5.522487e-07     17878.739100           18           1
# 2                 8.767526e-05     17877.855333           18           1
# 3                 6.519268e-02     17220.713150           18          10
# 4                 5.900645e-04     17214.765300           18          10
# ...                        ...              ...          ...         ...
# 115120            1.104878e-04      8779.704183           18         276
# 115121            7.569586e-01      1149.561000           18          85
# 115122            1.121890e-01        18.696367           18          62
# 115123            0.000000e+00         0.000000           18          61
# 115124            1.854798e-03         0.000000           18          61
#
#           label
# 0       regular
# 1       regular
# 2       regular
# 3       regular
# 4       regular
# ...         ...
# 115120  deviant
# 115121  deviant
# 115122  deviant
# 115123  deviant
# 115124  deviant
#
# [115125 rows x 23 columns]

# %%
set(data_offeres.NumberOfOffers)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
# function to add treatment based on the number of offers
def add_treatment(df):
    # function to cheack if a case contains A_Pending activity or not
    def check_NoOfOffers(gr):
        df = pd.DataFrame(gr)

        # case should be not treated if it receives more than one offer
        if list(df["NumberOfOffers"])[0] <= 1:
            df["treatment"] = "treat"  # T=1 pos_treatment
        else:
            df["treatment"] = "noTreat"  # T=0 neg_treatment
        return df

    # add new treatment for each case based on number of offers
    # cases with only one offer should be treated
    df = df.groupby(case_id_col).apply(check_NoOfOffers)
    df = df.reset_index(drop=True)
    return df


print("Add Treatment...")
data_treat = add_treatment(data_offeres)
data_treat
# Out:
# Add Treatment...
#         Case ID  NumberOfOffers              start_time  \
# 0        173688               1 2011-09-30 22:38:44.546
# 1        173688               1 2011-09-30 22:38:44.880
# 2        173688               1 2011-09-30 22:39:37.906
# 3        173688               1 2011-10-01 09:36:46.437
# 4        173688               1 2011-10-01 09:42:43.308
# ...         ...             ...                     ...
# 115120   214361               1 2012-03-07 08:01:59.877
# 115121   214361               1 2012-03-12 15:12:08.468
# 115122   214361               1 2012-03-13 10:03:00.346
# 115123   214361               1 2012-03-13 10:21:42.128
# 115124   214361               1 2012-03-13 10:21:42.128
#
#                        end_time  AMOUNT_REQ                  REG_DATE  \
# 0       2011-09-30T22:38:44.546       20000  2011-09-30T22:38:44.546Z
# 1       2011-09-30T22:38:44.880       20000  2011-09-30T22:38:44.546Z
# 2       2011-09-30T22:39:37.906       20000  2011-09-30T22:38:44.546Z
# 3       2011-10-01T09:45:13.917       20000  2011-09-30T22:38:44.546Z
# 4       2011-10-01T09:42:43.308       20000  2011-09-30T22:38:44.546Z
# ...                         ...         ...                       ...
# 115120  2012-03-07T08:01:59.877        5000  2012-02-29T22:11:37.974Z
# 115121  2012-03-12T15:12:34.634        5000  2012-02-29T22:11:37.974Z
# 115122  2012-03-13T10:21:45.661        5000  2012-02-29T22:11:37.974Z
# 115123  2012-03-13T10:21:42.128        5000  2012-02-29T22:11:37.974Z
# 115124  2012-03-13T10:21:42.128        5000  2012-02-29T22:11:37.974Z
#
#                       Activity  Resource  timesincemidnight  month  ...  \
# 0                  A_SUBMITTED     112.0               1358      9  ...
# 1            A_PARTLYSUBMITTED     112.0               1358      9  ...
# 2                A_PREACCEPTED     112.0               1359      9  ...
# 3       W_Completeren aanvraag     112.0                576     10  ...
# 4                   A_ACCEPTED   10862.0                582     10  ...
# ...                        ...       ...                ...    ...  ...
# 115120             O_SENT_BACK   10899.0                481      3  ...
# 115121    W_Valideren aanvraag   10809.0                912      3  ...
# 115122    W_Valideren aanvraag   10138.0                603      3  ...
# 115123              A_DECLINED   10138.0                621      3  ...
# 115124              O_DECLINED   10138.0                621      3  ...
#
#         event_nr  timesincecasestart_days  timesincecasestart_wks  \
# 0              1                 0.000000            0.000000e+00
# 1              2                 0.000004            5.522487e-07
# 2              3                 0.000618            8.822751e-05
# 3              4                 0.456966            6.528090e-02
# 4              5                 0.461097            6.587097e-02
# ...          ...                      ...                     ...
# 115120        14                 6.409976            9.157108e-01
# 115121        15                11.708686            1.672669e+00
# 115122        16                12.494009            1.784858e+00
# 115123        17                12.506993            1.786713e+00
# 115124        18                12.506993            1.786713e+00
#
#         timesincelastevent_days  timesincelastevent_wks  time_to_event_m  \
# 0                      0.000000            0.000000e+00     17878.744667
# 1                      0.000004            5.522487e-07     17878.739100
# 2                      0.000614            8.767526e-05     17877.855333
# 3                      0.456349            6.519268e-02     17220.713150
# 4                      0.004130            5.900645e-04     17214.765300
# ...                         ...                     ...              ...
# 115120                 0.000773            1.104878e-04      8779.704183
# 115121                 5.298711            7.569586e-01      1149.561000
# 115122                 0.785323            1.121890e-01        18.696367
# 115123                 0.000000            0.000000e+00         0.000000
# 115124                 0.012984            1.854798e-03         0.000000
#
#         case_length  open_cases    label  treatment
# 0                18           1  regular      treat
# 1                18           1  regular      treat
# 2                18           1  regular      treat
# 3                18          10  regular      treat
# 4                18          10  regular      treat
# ...             ...         ...      ...        ...
# 115120           18         276  deviant      treat
# 115121           18          85  deviant      treat
# 115122           18          62  deviant      treat
# 115123           18          61  deviant      treat
# 115124           18          61  deviant      treat
#
# [115125 rows x 24 columns]

# %%
data_all = data_treat
# impute missing values
print("impute missing values...")
grouped = data_all.sort_values(timestamp_col, ascending=True, kind="mergesort").groupby(
    case_id_col
)
for col in static_cols + dynamic_cols:
    data[col] = grouped[col].transform(lambda grp: grp.fillna(method="ffill"))

data_all[cat_cols] = data_all[cat_cols].fillna("missing")
data_all = data_all.fillna(0)

# set infrequent factor levels to "other"
for col in cat_cols:
    counts = data_all[col].value_counts()
    mask = data_all[col].isin(counts[counts >= freq_threshold].index)
    data_all.loc[~mask, col] = "other"
# Out:
# impute missing values...

# %%
del data_all["end_time"]
print("Saving csv file...")
results_dir = "./prepared_data/%s/" % dataset_name
import os

if not os.path.exists(os.path.join(results_dir)):
    os.makedirs(os.path.join(results_dir))

# df.to_csv(results_dir + '/prepared_treatment_outcome_bpic2012.csv', index=False, sep=';')
data_all["event"] = 1
data_all["event"] = data_all["event"].astype("bool")

data_all.to_csv(
    os.path.join(
        results_dir, "prepared_treatment_outcome_time_to_event_%s.csv" % dataset_name
    ),
    index=False,
    sep=";",
)
# Out:
# Saving csv file...
